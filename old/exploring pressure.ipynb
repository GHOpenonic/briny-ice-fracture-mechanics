# %% [markdown]
# ### This notebook utilizes data taken by an ESP8266 microcontroller via an MS5803-05BA sensor during freezing experiments to explore how pressure and temperature change throughout the freezing process.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 16, 'axes.labelsize': 18, 'legend.fontsize': 14})
# Out:
# C:\Users\Openo\anaconda3\lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
# load all data!
# 10-19-23
delimiters = r'[:,]'
water_data_10_19 = pd.read_csv('Pressure Data/-30_10-19-23/water_data.csv',sep=delimiters,header=None,engine='python')
length_10_19 = water_data_10_19.index.tolist()

# 10-23-23
delimiters = r'[:,]'
water_data_10_23 = pd.read_csv('Pressure Data/-30_10-23-23/water_data.csv',sep=delimiters,header=None,engine='python')
length_10_23 = water_data_10_23.index.tolist()

# 10-25-23
delimiters = r'[:,]'
water_data_10_25 = pd.read_csv('Pressure Data/-40_10-25-23/water_data.csv',sep=delimiters,header=None,engine='python')
length_10_25 = water_data_10_25.index.tolist()

# 10-26-23 Not plotting because ~40 min of fracture data was not taken due to errors
delimiters = r'[:,]'
water_data_10_26 = pd.read_csv('Pressure Data/-40_10-26-23_major_errors/water_data.csv',sep=delimiters,header=None,engine='python')
length_10_26 = water_data_10_26.index.tolist()

# 11-6-23
delimiters = r'[:,]'
water_data_11_6 = pd.read_csv('Pressure Data/-30_11-6-23/water_data.csv',sep=delimiters,header=None,engine='python')
length_11_6 = water_data_11_6.index.tolist()

# 11-15-23 CONTROL (SENSOR IS IN AIR)
delimiters = r'[:,]'
control = pd.read_csv('Pressure Data/-30_11-15-23 control/water_data.csv',sep=delimiters,header=None,engine='python')
control_length = control.index.tolist()

# 11-28-23 SALT 6 g/l
delimiters = r'[:,]'
salt_6_11_28 = pd.read_csv('Pressure Data/-30_11-28-23_salt_6_l/water_data.csv',sep=delimiters,header=None,engine='python')
salt_6_11_28_length = salt_6_11_28.index.tolist()

# %% [markdown]
# # get heat flux from initial temp drop. heat flux = rhocp dT/dt

# %%
plt.rcParams.update({'font.size': 16})
fig, ax1 = plt.subplots()
ax1.plot((np.array(salt_6_11_28_length) * 30) / 60 / 60, salt_6_11_28[1], 'b', label='Pressure')
ax1.set_xlabel('hours',fontsize=22)
ax1.set_ylabel('millibars', color='b', fontsize = 22)
ax1.tick_params('y', colors='b', labelsize=12)
ax1.set_xticks(np.arange(0, len(length_11_6), step=1))
plt.ylim(0,3500)

ax2 = ax1.twinx()
ax2.plot((np.array(salt_6_11_28_length) * 30) / 60 / 60, salt_6_11_28[3], 'r', label='Temperature', linestyle = '--')
ax2.set_ylabel('°C', color='r', fontsize =22)
ax2.tick_params('y', colors='r', labelsize=12)

ax1.legend(loc='lower left', fontsize=12, bbox_to_anchor=(0, 0.08))
ax2.legend(loc='lower left', fontsize=12)
#plt.suptitle('11/6/23', fontsize = 14)
#plt.title('Salted 6g/l Frozen at -30 °C',fontsize=22)
plt.xlim(1,3)
#print('note that this sample was not water or air tight as evidenced by drips through the pressure sensor seal')
#plt.savefig('Pressure Temperature FirstTrial.png', dpi=300, bbox_inches='tight')
#plt.savefig('Pressure_Salt_6g 11-28-23.png', dpi=450, bbox_inches='tight')
plt.show()

# %%
plt.rcParams.update({'font.size': 16})
fig, ax1 = plt.subplots()
ax1.plot((np.array(length_11_6) * 30) / 60 / 60, water_data_11_6[1], 'b', label='Pressure')
ax1.set_xlabel('hours',fontsize=22)
ax1.set_ylabel('millibars', color='b', fontsize = 22)
ax1.tick_params('y', colors='b', labelsize=12)
ax1.set_xticks(np.arange(0, len(length_11_6), step=1))

ax2 = ax1.twinx()
ax2.plot((np.array(length_11_6) * 30) / 60 / 60, water_data_11_6[3], 'r', label='Temperature', linestyle = '--')
ax2.set_ylabel('°C', color='r', fontsize =22)
ax2.tick_params('y', colors='r', labelsize=12)

ax1.legend(loc='lower left', fontsize=12, bbox_to_anchor=(0, 0.08))
ax2.legend(loc='lower left', fontsize=12)
#plt.suptitle('11/6/23', fontsize = 14)
#plt.title('Unsalted Frozen at -30 °C',fontsize=22)
plt.xlim(1,3)
#print('note that this sample was not water or air tight as evidenced by drips through the pressure sensor seal')
#plt.savefig('Pressure Temperature FirstTrial.png', dpi=300, bbox_inches='tight')
#plt.savefig('Pressure Temperature 11-6-23.png', dpi=450, bbox_inches='tight')
plt.show()

# %%
print(len((np.array(length_11_6) * 30) / 60 / 60))
len(water_data_11_6[1])
# Out:
# 796
# 796

# %%
plt.scatter(np.array(salt_6_11_28_length) * 30 / 60 / 60, salt_6_11_28[1])

# %%
plt.scatter(np.array(length_11_6) * 30 / 60 / 60, water_data_11_6[1])

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, sharey=True, figsize=(12, 6))

# Plot 1
ax1.plot((np.array(salt_6_11_28_length) * 30) / 60 / 60, salt_6_11_28[1], 'b', label='pressure')
ax1.set_xlabel('hours', fontsize=28)
ax1.set_ylabel('millibars', color='b', fontsize=28)
ax1.tick_params('y', colors='b', labelsize=20)
ax1.set_xticks(np.arange(0, len(length_11_6), step=1))
ax1.set_ylim(0, 3500)

ax2_1 = ax1.twinx()
ax2_1.plot((np.array(salt_6_11_28_length) * 30) / 60 / 60, salt_6_11_28[3], 'r', label='Temperature', linestyle='--')
ax2_1.set_yticks([])  # Remove y-axis ticks
ax2_1.set_yticklabels([])  # Remove y-axis tick labels

ax1.legend(loc='lower left', fontsize=16, bbox_to_anchor=(0, 0.08))
ax2_1.legend(loc='lower left', fontsize=16)

ax1.set_xlim(0, 5)
ax1.set_title('A', fontsize = 36)

# Plot 2
ax2.plot((np.array(length_11_6) * 30) / 60 / 60, water_data_11_6[1], 'b', label='pressure')
ax2.set_xlabel('hours', fontsize=26)
ax2.set_xticks(np.arange(0, len(length_11_6), step=1))

ax2_2 = ax2.twinx()
ax2_2.plot((np.array(length_11_6) * 30) / 60 / 60, water_data_11_6[3], 'r', label='Temperature', linestyle='--')
ax2_2.set_ylabel('°C', color='r', fontsize=28)
ax2_2.tick_params('y', colors='r', labelsize=20)

#ax2.legend(loc='lower left', fontsize=12, bbox_to_anchor=(0, 0.08))
#ax2_2.legend(loc='lower left', fontsize=12)

ax2.set_xlim(0, 5)
ax2.set_title('B', fontsize = 36)

plt.tight_layout()
#plt.savefig('temp_pressure_measurement_paper.png', dpi=450, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Calculate running mean of pressure

# %%
plt.rcParams.update({'font.size': 20, 'axes.labelsize': 26, 'legend.fontsize': 20})
# List of window sizes
window_sizes = [1, 5, 10, 20,30,40]

# Create a grid of subplots
fig, axes = plt.subplots(len(window_sizes), 2, sharey=True, figsize=(22,30))

# Loop through each window size and plot the results
for i, window_size in enumerate(window_sizes):
    salt_running = salt_6_11_28[1].rolling(window=window_size).mean()
    water_running = water_data_11_6[1].rolling(window=window_size).mean()

    # Plot 1
    axes[i, 0].plot((np.array(salt_6_11_28_length) * 30) / 60 / 60, salt_running, 'b', label='pressure')
    axes[i, 0].set_xlabel('hours', fontsize=12)
    axes[i, 0].set_ylabel('millibars', color='b', fontsize=12)
    axes[i, 0].tick_params('y', colors='b', labelsize=8)
    axes[i, 0].set_xticks(np.arange(0, len(length_11_6), step=1))
    axes[i, 0].set_xlim(0, 5)
    axes[i, 0].set_ylim(0, 3500)
    axes[i, 0].set_title(f'Running Mean Salty (Window Size {window_size})')

    ax2_1 = axes[i, 0].twinx()
    ax2_1.plot((np.array(salt_6_11_28_length) * 30) / 60 / 60, salt_6_11_28[3], 'r', label='Temperature', linestyle='--')
    ax2_1.set_ylabel('°C', color='r', fontsize=12)
    ax2_1.tick_params('y', colors='r', labelsize=8)

    axes[i, 0].legend(loc='lower left', fontsize=8, bbox_to_anchor=(0, 0.08))
    ax2_1.legend(loc='lower left', fontsize=8)

    # Plot 2
    axes[i, 1].plot((np.array(length_11_6) * 30) / 60 / 60, water_running, 'b', label='pressure')
    axes[i, 1].set_xlabel('hours', fontsize=12)
    axes[i, 1].set_xticks(np.arange(0, len(length_11_6), step=1))

    ax2_2 = axes[i, 1].twinx()
    ax2_2.plot((np.array(length_11_6) * 30) / 60 / 60, water_data_11_6[3], 'r', label='Temperature', linestyle='--')
    ax2_2.set_ylabel('°C', color='r', fontsize=12)
    ax2_2.tick_params('y', colors='r', labelsize=8)

    axes[i, 1].legend(loc='lower left', fontsize=8, bbox_to_anchor=(0, 0.08))
    ax2_2.legend(loc='lower left', fontsize=8)

    axes[i, 1].set_xlim(0, 5)
    axes[i, 1].set_title(f'Running Mean Fresh (Window Size {window_size})')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Calculate time derivative of pressure

# %%
salt_6_11_28_dp_dt = np.gradient(salt_6_11_28[1], (np.array(salt_6_11_28_length) * 30))
water_data_11_6_dp_dt = np.gradient(water_data_11_6[1], (np.array(length_11_6) * 30))

# %%
plt.rcParams.update({'font.size': 16, 'axes.labelsize': 18, 'legend.fontsize': 14})
fig, (ax1, ax2) = plt.subplots(1, 2, sharey='row', figsize=(12, 6))

# Plot 1
ax1.plot((np.array(salt_6_11_28_length) * 30) / 60 / 60, salt_6_11_28_dp_dt, 'b', label='dp/dt')
ax1.set_xlabel('hours', fontsize=22)
ax1.set_ylabel('dp/dt (millibars/second)', color='b', fontsize=22)
ax1.tick_params('y', colors='b', labelsize=12)
ax1.set_xticks(np.arange(0, len(length_11_6), step=1))
ax1.set_ylim(-50, 50)

ax2_1 = ax1.twinx()
ax2_1.plot((np.array(salt_6_11_28_length) * 30) / 60 / 60, salt_6_11_28[3], 'r', label='Temperature', linestyle='--')
ax2_1.set_ylabel('°C', color='r', fontsize=22)
ax2_1.tick_params('y', colors='r', labelsize=12)

ax1.legend(loc='lower left', fontsize=12, bbox_to_anchor=(0, 0.08))
ax2_1.legend(loc='lower left', fontsize=12)

ax1.set_xlim(0, 5)
ax1.set_title('6 g/l salty')

# Plot 2
ax2.plot((np.array(length_11_6) * 30) / 60 / 60, water_data_11_6_dp_dt, 'b', label='dp/dt')
ax2.set_xlabel('hours', fontsize=22)
ax2.set_xticks(np.arange(0, len(length_11_6), step=1))

ax2_2 = ax2.twinx()
ax2_2.plot((np.array(length_11_6) * 30) / 60 / 60, water_data_11_6[3], 'r', label='Temperature', linestyle='--')
ax2_2.set_ylabel('°C', color='r', fontsize=22)
ax2_2.tick_params('y', colors='r', labelsize=12)

ax2.legend(loc='lower left', fontsize=12, bbox_to_anchor=(0, 0.08))
ax2_2.legend(loc='lower left', fontsize=12)

ax2.set_xlim(0, 5)
ax2.set_title('fresh')


plt.tight_layout()
plt.show()

# %%
# Pa conversion

# %% [markdown]
# ## try fourier transforms of dp/dt and p

# %%
# Sample data for water dp/dt
time_water_dp_dt = np.arange(0, len(water_data_11_6_dp_dt)) * 30  # Assuming data is sampled every 30 seconds
pressure_water_dp_dt = water_data_11_6_dp_dt

# FFT calculation for water dp/dt
fft_result_water_dp_dt = np.fft.fft(pressure_water_dp_dt)
freq_water_dp_dt = np.fft.fftfreq(len(pressure_water_dp_dt), d=30)  # d is the sample spacing (30 seconds)

# Sample data for water pressure
time_water = np.arange(0, len(water_data_11_6)) * 30  # Assuming data is sampled every 30 seconds
pressure_water = water_data_11_6[1]

# FFT calculation for water pressure
fft_result_water = np.fft.fft(pressure_water)
freq_water = np.fft.fftfreq(len(pressure_water), d=30)  # d is the sample spacing (30 seconds)

# Plotting
plt.figure(figsize=(16, 8))

# Subplot 1: Original signal for water dp/dt
plt.subplot(2, 2, 1)
plt.plot(time_water_dp_dt, pressure_water_dp_dt, label='Water dp/dt - Original Signal')
plt.xlabel('Time (seconds)')
plt.ylabel('dp/dt')
plt.legend()

# Subplot 2: FFT result for water dp/dt
plt.subplot(2, 2, 2)
plt.plot(freq_water_dp_dt, np.abs(fft_result_water_dp_dt))
plt.xlabel('Frequency (Hz)')
plt.ylabel('Amplitude')
plt.title('Water dp/dt - FFT Result')

# Subplot 3: Original signal for water pressure
plt.subplot(2, 2, 3)
plt.plot(time_water, pressure_water, label='Water - Original Signal')
plt.xlabel('Time (seconds)')
plt.ylabel('Pressure')
plt.legend()

# Subplot 4: FFT result for water pressure
plt.subplot(2, 2, 4)
plt.plot(freq_water, np.abs(fft_result_water))
plt.xlabel('Frequency (Hz)')
plt.ylabel('Amplitude')
plt.title('Water - FFT Result')

plt.tight_layout()
plt.show()

# %%
# Sample data for salt dp/dt
time_salt_dp_dt = np.arange(0, len(salt_6_11_28_dp_dt[:400])) * 30  # Assuming data is sampled every 30 seconds
pressure_salt_dp_dt = salt_6_11_28_dp_dt[:400]

# FFT calculation for salt dp/dt
fft_result_salt_dp_dt = np.fft.fft(pressure_salt_dp_dt)
freq_salt_dp_dt = np.fft.fftfreq(len(pressure_salt_dp_dt), d=30)  # d is the sample spacing (30 seconds)

# Sample data for salt pressure
time_salt = np.arange(0, len(salt_6_11_28[:400])) * 30  # Assuming data is sampled every 30 seconds
pressure_salt = salt_6_11_28[1][:400]

# FFT calculation for salt pressure
fft_result_salt = np.fft.fft(pressure_salt)
freq_salt = np.fft.fftfreq(len(pressure_salt), d=30)  # d is the sample spacing (30 seconds)

# Plotting
plt.figure(figsize=(16, 8))

# Subplot 1: Original signal for salt dp/dt
plt.subplot(2, 2, 1)
plt.plot(time_salt_dp_dt, pressure_salt_dp_dt, label='Salt dp/dt - Original Signal')
plt.xlabel('Time (seconds)')
plt.ylabel('dp/dt')
plt.legend()

# Subplot 2: FFT result for salt dp/dt
plt.subplot(2, 2, 2)
plt.plot(freq_salt_dp_dt, np.abs(fft_result_salt_dp_dt))
plt.xlabel('Frequency (Hz)')
plt.ylabel('Amplitude')
plt.title('Salt dp/dt - FFT Result')

# Subplot 3: Original signal for salt pressure
plt.subplot(2, 2, 3)
plt.plot(time_salt, pressure_salt, label='Salt - Original Signal')
plt.xlabel('Time (seconds)')
plt.ylabel('Pressure')
plt.legend()

# Subplot 4: FFT result for salt pressure
plt.subplot(2, 2, 4)
plt.plot(freq_salt, np.abs(fft_result_salt))
plt.xlabel('Frequency (Hz)')
plt.ylabel('Amplitude')
plt.title('Salt - FFT Result')

plt.tight_layout()
plt.show()

# %%
# log log scaling

# %%
plt.rcParams.update({'font.size': 16})
fig, ax1 = plt.subplots()
ax1.plot(length_10_19, water_data_10_19[1], 'b', label='Pressure')
ax1.set_xlabel('Measurement # (~1 Measurement/30 sec)',fontsize=14)
ax1.set_ylabel('millibars', color='b')
ax1.tick_params('y', colors='b', labelsize=12)

ax2 = ax1.twinx()
ax2.plot(length_10_19, water_data_10_19[3], 'r', label='Temperature')
ax2.set_ylabel('°C', color='r')
ax2.tick_params('y', colors='r', labelsize=12)

ax1.legend(loc='lower left', fontsize=12)
ax2.legend(loc='upper right', fontsize=12)
plt.title('10-19-23 Pressure and Temperature by Measurement #')
plt.suptitle('Frozen at -30 °C',fontsize=12)
plt.xlim()
#plt.savefig('Pressure Temperature FirstTrial.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
plt.rcParams.update({'font.size': 16})
fig, ax1 = plt.subplots()
ax1.plot(length_10_23, water_data_10_23[1], 'b', label='Pressure')
ax1.set_xlabel('Measurement # (~1 Measurement/30 sec)',fontsize=14)
ax1.set_ylabel('millibars', color='b')
ax1.tick_params('y', colors='b', labelsize=12)

ax2 = ax1.twinx()
ax2.plot(length_10_23, water_data_10_23[3], 'r', label='Temperature')
ax2.set_ylabel('°C', color='r')
ax2.tick_params('y', colors='r', labelsize=12)

ax1.legend(loc='lower left', fontsize=12)
ax2.legend(loc='upper right', fontsize=12)
plt.title('10-23-23 Pressure and Temperature by Measurement #')
plt.suptitle('Frozen at -30 °C',fontsize=12)
#plt.xlim(150,300)
#plt.savefig('Pressure Temperature FirstTrial.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
plt.rcParams.update({'font.size': 16})
fig, ax1 = plt.subplots()
ax1.plot(length_10_19, water_data_10_19[1], 'b', label='Pressure run 1')
ax1.plot(length_10_23, water_data_10_23[1], 'c',linestyle='--', label='Pressure run 2')
ax1.set_xlabel('Measurement # (~1 Measurement/30 sec)',fontsize=14)
ax1.set_ylabel('millibars', color='b')
ax1.tick_params('y', colors='b', labelsize=12)

ax2 = ax1.twinx()
ax2.plot(length_10_19, water_data_10_19[3], 'r', label='Temperature run 1')
ax2.plot(length_10_23, water_data_10_23[3], 'orange',linestyle='--', label='Temperature run 2')
ax2.set_ylabel('°C', color='r')
ax2.tick_params('y', colors='r', labelsize=12)

ax1.legend(loc='lower left', fontsize=12)
ax2.legend(loc='upper right', fontsize=12)
plt.title('10-19-23 vs 10-23-23')
plt.suptitle('Frozen at -30 °C',fontsize=12)
#plt.savefig('Pressure Temperature FirstTrial.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
plt.rcParams.update({'font.size': 16})
fig, ax1 = plt.subplots()
ax1.plot(length_10_25, water_data_10_25[1], 'b', label='Pressure')
ax1.set_xlabel('Measurement # (~1 Measurement/30 sec)',fontsize=14)
ax1.set_ylabel('millibars', color='b')
ax1.tick_params('y', colors='b', labelsize=12)
#plt.ylim(1000,1100)
ax2 = ax1.twinx()
ax2.plot(length_10_25, water_data_10_25[3], 'r', label='Temperature')
ax2.set_ylabel('°C', color='r')
ax2.tick_params('y', colors='r', labelsize=12)

ax1.legend(loc='lower left', fontsize=12)
ax2.legend(loc='upper right', fontsize=12)
plt.title('10-25-23 Pressure and Temperature by Measurement #')
plt.suptitle('Frozen at -40 °C',fontsize=12)
#plt.xlim(0, 70)
#plt.savefig('Pressure Temperature FirstTrial.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# CONTROL
plt.rcParams.update({'font.size': 16})
fig, ax1 = plt.subplots()
ax1.plot(control_length, control[1], 'b', label='Pressure')
ax1.set_xlabel('Measurement # (~1 Measurement/30 sec)',fontsize=14)
ax1.set_ylabel('millibars', color='b')
ax1.tick_params('y', colors='b', labelsize=12)

ax2 = ax1.twinx()
ax2.plot(control_length, control[3], 'r', label='Temperature')
ax2.set_ylabel('°C', color='r')
ax2.tick_params('y', colors='r', labelsize=12)

ax1.legend(loc='upper right', fontsize=12)
ax2.legend(loc='lower left', fontsize=12)
plt.title('control temp and pressure')
#plt.suptitle('in air',fontsize=12)
plt.xlim()
print('note that this sample was not in water. It was to see the temperature impact on the variability of pressure')
#plt.savefig('Pressure Temperature FirstTrial.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# note that this sample was not in water. It was to see the temperature impact on the variability of pressure
