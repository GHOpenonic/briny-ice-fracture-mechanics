# %% [markdown]
# ### This notebook utilizes data taken by an ESP8266 microcontroller via an MS5803-05BA sensor during freezing experiments to explore the relationship between the freezing rate and initial gain in pressure

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# load all data
# 10-19-23
delimiters = r'[:,]'
water_data_10_19 = pd.read_csv('Pressure Data/-30_10-19-23/water_data.csv',sep=delimiters,header=None,engine='python')
length_10_19 = water_data_10_19.index.tolist()

# 10-23-23
delimiters = r'[:,]'
water_data_10_23 = pd.read_csv('Pressure Data/-30_10-23-23/water_data.csv',sep=delimiters,header=None,engine='python')
length_10_23 = water_data_10_23.index.tolist()

# 10-25-23
delimiters = r'[:,]'
water_data_10_25 = pd.read_csv('Pressure Data/-40_10-25-23/water_data.csv',sep=delimiters,header=None,engine='python')
length_10_25 = water_data_10_25.index.tolist()

# 10-26-23 Not plotting because ~40 min of fracture data was not taken due to errors
delimiters = r'[:,]'
water_data_10_26 = pd.read_csv('Pressure Data/-40_10-26-23_major_errors/water_data.csv',sep=delimiters,header=None,engine='python')
length_10_26 = water_data_10_26.index.tolist()

# 11-6-23
delimiters = r'[:,]'
water_data_11_6 = pd.read_csv('Pressure Data/-30_11-6-23/water_data.csv',sep=delimiters,header=None,engine='python')
length_11_6 = water_data_11_6.index.tolist()

# 11-15-23 CONTROL (SENSOR IS IN AIR)
delimiters = r'[:,]'
control = pd.read_csv('Pressure Data/-30_11-15-23 control/water_data.csv',sep=delimiters,header=None,engine='python')
control_length = control.index.tolist()

# 11-28-23 SALT 6 g/l
delimiters = r'[:,]'
salt_6_11_28 = pd.read_csv('Pressure Data/-30_11-28-23_salt_6_l/water_data.csv',sep=delimiters,header=None,engine='python')
salt_6_11_28_length = salt_6_11_28.index.tolist()

# 1-22-24 SALT 3 g/l
delimiters = r'[:,]'
salt_3_1_22 = pd.read_csv('Pressure Data/-30_1-22-24_salt_3_l/water_data.csv',sep=delimiters,header=None,engine='python')
salt_3_1_22_length = salt_3_1_22.index.tolist()

# 1-23-24 
delimiters = r'[:,]'
pre_end__1_23 = pd.read_csv('Pressure Data/-30_1_23_2024_premature_end/water_data.csv',sep=delimiters,header=None,engine='python')
pre_end__1_23_length = pre_end__1_23.index.tolist()

# %%
plt.rcParams.update({'font.size': 16})
fig, ax1 = plt.subplots()
ax1.plot((np.array(pre_end__1_23_length) * 30) / 60 / 60, pre_end__1_23[1], 'b', label='Pressure')
ax1.set_xlabel('hours',fontsize=22)
ax1.set_ylabel('millibars', color='b', fontsize = 22)
ax1.tick_params('y', colors='b', labelsize=12)
ax1.set_xticks(np.arange(0, len(length_11_6), step=1))
plt.ylim(0,3500)

ax2 = ax1.twinx()
ax2.plot((np.array(pre_end__1_23_length) * 30) / 60 / 60, pre_end__1_23[3], 'r', label='Temperature')
ax2.set_ylabel('°C', color='r', fontsize =22)
ax2.tick_params('y', colors='r', labelsize=12)

ax1.legend(loc='lower left', fontsize=12, bbox_to_anchor=(0, 0.08))
ax2.legend(loc='lower left', fontsize=12)
#plt.xlim(0,1.25)




ax2.plot(np.array(length_11_6) * 30 / 60 / 60, water_data_11_6[3], 'r', label='Temperature',linestyle = '--')

ax1.plot(np.array(length_11_6) * 30 / 60 / 60, water_data_11_6[1], 'b', label='Pressure', linestyle = '--')
plt.xlim(0,3)

plt.title('Fresh 1-23-24 P and T end early')
plt.suptitle('Frozen at -30 °C',fontsize=12)

plt.show()

# %%
plt.rcParams.update({'font.size': 16})
fig, ax1 = plt.subplots()
ax1.plot(salt_3_1_22_length, salt_3_1_22[1], 'b', label='Pressure')
ax1.set_xlabel('Measurement # (~1 Measurement/30 sec)',fontsize=14)
ax1.set_ylabel('millibars', color='b')
ax1.tick_params('y', colors='b', labelsize=12)

ax2 = ax1.twinx()
ax2.plot(salt_3_1_22_length, salt_3_1_22[3], 'r', label='Temperature')
ax2.set_ylabel('°C', color='r')
ax2.tick_params('y', colors='r', labelsize=12)

ax1.legend(loc='lower left', fontsize=12)
ax2.legend(loc='upper right', fontsize=12)
plt.title('SALT 3 g/l 1-22-24 Pressure and Temperature by Measurement #')
plt.suptitle('Frozen at -30 °C',fontsize=12)
#plt.xlim(276,280)
#plt.savefig('Pressure Temperature FirstTrial.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
plt.rcParams.update({'font.size': 16})
fig, ax1 = plt.subplots()
ax1.plot(length_11_6, water_data_11_6[1], 'b', label='Pressure')
ax1.set_xlabel('Measurement # (~1 Measurement/30 sec)',fontsize=14)
ax1.set_ylabel('millibars', color='b')
ax1.tick_params('y', colors='b', labelsize=12)

ax2 = ax1.twinx()
ax2.plot(length_11_6, water_data_11_6[3], 'r', label='Temperature')
ax2.set_ylabel('°C', color='r')
ax2.tick_params('y', colors='r', labelsize=12)

ax1.legend(loc='lower left', fontsize=12)
ax2.legend(loc='upper right', fontsize=12)
plt.title('11-6-23 Pressure and Temperature by Measurement #')
plt.suptitle('Frozen at -30 °C',fontsize=12)
plt.xlim(60,400)
print('note that this sample was not water or air tight as evidenced by drips through the pressure sensor seal')
#plt.savefig('Pressure Temperature FirstTrial.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# note that this sample was not water or air tight as evidenced by drips through the pressure sensor seal

# %% [markdown]
# From the figure above, let's isolate the intial drop in temperature and find the freezing rate at -30C

# %%
from scipy.fft import fft, fftshift, fftfreq
p = np.array(water_data_11_6[1])
p2 = np.array(salt_6_11_28[1][0:200])
n = len(p)
n2 = len(p2)
f = fftshift(fftfreq(n,d=30))
ft = fftshift(fft(p))

f2 = fftshift(fftfreq(n2,d=30))
ft2 = fftshift(fft(p2))

plt.loglog(f,np.abs(ft))
plt.loglog(f2,np.abs(ft2))
plt.xlabel('Frequency, Hz')
plt.show()

# %%
plt.rcParams.update({'font.size': 16})
fig, ax1 = plt.subplots()
ax1.plot(length_11_6, water_data_11_6[1], 'b', label='Pressure')
ax1.set_xlabel('Measurement # (~1 Measurement/30 sec)',fontsize=14)
ax1.set_ylabel('millibars', color='b')
ax1.tick_params('y', colors='b', labelsize=12)

ax2 = ax1.twinx()
ax2.plot(length_11_6, water_data_11_6[3], 'r', label='Temperature')
ax2.set_ylabel('°C', color='r')
ax2.tick_params('y', colors='r', labelsize=12)

ax1.legend(loc='lower left', fontsize=12)
ax2.legend(loc='upper right', fontsize=12)
plt.title('11-6-23 Pressure and Temperature by Measurement #')
plt.suptitle('Frozen at -30 °C',fontsize=12)
plt.xlim(0,100)
print('note that this sample was not water or air tight as evidenced by drips through the pressure sensor seal')
#plt.savefig('Pressure Temperature FirstTrial.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# note that this sample was not water or air tight as evidenced by drips through the pressure sensor seal

# %% [markdown]
# So 10 to 60 measurements is about right <br>
# Let's find the approx. linear freezing rate <br>

# %%
# finding dT/dt
temp_11_6 = water_data_11_6[3]
intial_temp_drop_11_6 = np.array(temp_11_6[10:60])
dt = np.array(length_11_6[10:60]) * 30
dT_length = np.linspace(10*30,60*30,100)

# %%
T_fit = np.poly1d(np.polyfit(dt,intial_temp_drop_11_6,1)) # linear fit
print('T = ' + str(T_fit) + ' where x is time')
# Out:
# T =
# -0.0142 x + 24.56 where x is time

# %%
plt.plot(dt, intial_temp_drop_11_6, label = 'data',linewidth = 3)
plt.plot(dT_length,T_fit(dT_length), label = T_fit,linewidth = 3)
plt.xlabel('seconds)',fontsize=14)
plt.ylabel('temperature')
plt.title('data vs dT/dt')
plt.legend()

# %% [markdown]
# ## $$
#   Q_{est} = \rho_{water}  C_p  \frac{dT}{dt}
# $$

# %% [markdown]
# multiply q_est by V to get in watts

# %% [markdown]
# From the linear fit T = -0.0142 x + 24.56, our rate of heating value is -0.0142 <br>
# let's calculate Q_est now

# %%
rho_water = 1000 # set water density to 1000 kg / m^3
C_p = 4181 # set heat capacity of water to 4181 j / kg C
dT_dt = round(T_fit.coef[0],4) # set rate of heating to output of polyfit
dT_dt = dT_dt * -1 # turn rate of heating into rate of cooling
Q_est = rho_water * C_p * dT_dt / 1000
print(f'the estimated rate of freezing is {round(Q_est)}')
# Out:
# the estimated rate of freezing is 59

# %% [markdown]
# now, let's calculate the ice mass formation rate <br>
#
# ## $$
#   \dot{Mass_{ice}} = \frac{Q_{est}}{ l_f \rho_{ice}}
# $$

# %%
l_f = 334000 # set specific latent heat of fusion per unit mass to 334,000 j / kg
#rho_water = 1000  # set water density to 1000 kg / m^3
Mass_ice = Q_est / (l_f)
print(f'the estimated growth of ice in mass per second is {(Mass_ice)}')
# Out:
# the estimated growth of ice in mass per second is 0.0001777550898203593

# %% [markdown]
# now that we have our ice mass growth rate, let's find the rate of change in volume of a unit sphere defined as having radius = 1 <br>
# ## $$
#   \dot{Volume_{ice}} = \frac{1}{\rho_{ice}} \dot{Mass_{ice}}
# $$

# %%
rho_ice = 917 # set ice density to 917 kg / m^3
Volume_ice = Mass_ice/ rho_ice
print(f'the estimated change in volume per second is {(Volume_ice)}')
# Out:
# the estimated change in volume per second is 1.9384415465688038e-07

# %% [markdown]
# Now, let's calculate the change in pressure <br>
#
# ## $$
#   \dot{Pressure} = \frac{k_f}{v_0} \dot{Volume_{ice}}
# $$

# %%
k_f = 1.96 * 10**9 # set bulk modulus of water to 1.96*10^9 pascals
v_0 = 4/3 * np.pi * 1**3 # set initial sphere volume (as liquid)
pressure_change = Volume_ice * k_f / v_0
print(f'the estimated change in pressure in pascals per second is {(pressure_change)}')
print(f'the estimated change in pressure in millibars per second is {(pressure_change / 100)}')
# Out:
# the estimated change in pressure in pascals per second is 90.70269088515033
# the estimated change in pressure in millibars per second is 0.9070269088515033

# %% [markdown]
# This is a little more than twice a rough estimate of the initial experimental change in pressure shown below, they are of the same order of magnitude

# %%
#rough calculation:
time_change = (300-200) * 30
pressure_change = 2200 - 1000
dp_dt = pressure_change / time_change
print(dp_dt)
# Out:
# 0.4

# %%
plt.rcParams.update({'font.size': 16})
fig, ax1 = plt.subplots()
ax1.plot(length_11_6, water_data_11_6[1], 'b', label='Pressure')
ax1.set_xlabel('Measurement # (~1 Measurement/30 sec)',fontsize=14)
ax1.set_ylabel('millibars', color='b')
ax1.tick_params('y', colors='b', labelsize=12)

ax2 = ax1.twinx()
ax2.plot(length_11_6, water_data_11_6[3], 'r', label='Temperature')
ax2.set_ylabel('°C', color='r')
ax2.tick_params('y', colors='r', labelsize=12)

ax1.legend(loc='lower left', fontsize=12)
ax2.legend(loc='upper right', fontsize=12)
plt.title('11-6-23 Pressure and Temperature by Measurement #')
plt.suptitle('Frozen at -30 °C',fontsize=12)
plt.xlim(200,325)
print('note that this sample was not water or air tight as evidenced by drips through the pressure sensor seal')
#plt.savefig('Pressure Temperature FirstTrial.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# note that this sample was not water or air tight as evidenced by drips through the pressure sensor seal

# %% [markdown]
# ### Let's do the same but with a saltwater sample!

# %%
plt.rcParams.update({'font.size': 16})
fig, ax1 = plt.subplots()
ax1.plot((np.array(salt_6_11_28_length) * 30) / 60 / 60, salt_6_11_28[1], 'b', label='Pressure')
ax1.set_xlabel('hours',fontsize=22)
ax1.set_ylabel('millibars', color='b', fontsize = 22)
ax1.tick_params('y', colors='b', labelsize=12)
ax1.set_xticks(np.arange(0, len(length_11_6), step=1))
plt.ylim(0,3500)

ax2 = ax1.twinx()
ax2.plot((np.array(salt_6_11_28_length) * 30) / 60 / 60, salt_6_11_28[3], 'r', label='Temperature', linestyle = '--')
ax2.set_ylabel('°C', color='r', fontsize =22)
ax2.tick_params('y', colors='r', labelsize=12)

ax1.legend(loc='lower left', fontsize=12, bbox_to_anchor=(0, 0.08))
ax2.legend(loc='lower left', fontsize=12)
#plt.suptitle('11/6/23', fontsize = 14)
#plt.title('Salted 6g/l Frozen at -30 °C',fontsize=22)
plt.xlim(0,5)
#print('note that this sample was not water or air tight as evidenced by drips through the pressure sensor seal')
#plt.savefig('Pressure Temperature FirstTrial.png', dpi=300, bbox_inches='tight')
#plt.savefig('Pressure_Salt_6g 11-28-23.png', dpi=450, bbox_inches='tight')
plt.show()

# %% [markdown]
# From the figure above, let's isolate the intial drop in temperature and find the freezing rate at -30C

# %%
plt.rcParams.update({'font.size': 16})
fig, ax1 = plt.subplots()
ax1.plot((np.array(salt_6_11_28_length)), salt_6_11_28[1], 'b', label='Pressure')
ax1.set_xlabel('measurement number',fontsize=22)
ax1.set_ylabel('millibars', color='b', fontsize = 22)
ax1.tick_params('y', colors='b', labelsize=12)
ax1.set_xticks(np.arange(0, len(length_11_6), step=30))
plt.ylim(0,3500)

ax2 = ax1.twinx()
ax2.plot((np.array(salt_6_11_28_length)), salt_6_11_28[3], 'r', label='Temperature', linestyle = '--')
ax2.set_ylabel('°C', color='r', fontsize =22)
ax2.tick_params('y', colors='r', labelsize=12)

ax1.legend(loc='lower left', fontsize=12, bbox_to_anchor=(0, 0.08))
ax2.legend(loc='lower left', fontsize=12)
#plt.suptitle('11/6/23', fontsize = 14)
#plt.title('Salted 6g/l Frozen at -30 °C',fontsize=22)
plt.xlim(0,60)
#print('note that this sample was not water or air tight as evidenced by drips through the pressure sensor seal')
#plt.savefig('Pressure Temperature FirstTrial.png', dpi=300, bbox_inches='tight')
#plt.savefig('Pressure_Salt_6g 11-28-23.png', dpi=450, bbox_inches='tight')
plt.show()

# %% [markdown]
# So 15 to 60 measurement number is about right <br>
# Let's find the approx. linear freezing rate

# %%
# finding dT/dt
temp_11_28 = salt_6_11_28[3]
intial_temp_drop_11_28 = np.array(temp_11_28[10:60])
dt = np.array(salt_6_11_28_length[10:60]) * 30
dT_length = np.linspace(10*30,60*30,100)

# %%
T_fit = np.poly1d(np.polyfit(dt,intial_temp_drop_11_28,1)) # linear fit
print('T = ' + str(T_fit) + ' where x is time')
# Out:
# T =
# -0.01493 x + 28.96 where x is time

# %%
plt.plot(dt, intial_temp_drop_11_28, label = 'data',linewidth = 3)
plt.plot(dT_length,T_fit(dT_length), label = T_fit,linewidth = 3)
plt.xlabel('seconds)',fontsize=14)
plt.ylabel('temperature')
plt.title('data vs dT/dt')
plt.legend()

# %% [markdown]
# ## $$
#   Q_{est} = \rho_{water}  C_p  \frac{dT}{dt}
# $$
# ## $$
#   \dot{Mass_{ice}} = \frac{Q_{est}}{ l_f \rho_{ice}}
# $$
# ## $$
#   \dot{Pressure} = \frac{k_f}{v_0} \dot{Volume_{ice}}
# $$

# %%
mass_water = 950 + 6 #(water plus salt)
volume_water = 950
rho_water =  1000 * (mass_water / volume_water)  # set water density to 1000 kg / m^3 + g grams of salt

heat_capacity_water = 950 * 4.18
heat_capacity_salt = 6 * 0.85
specific_heat_capacity_both = heat_capacity_water + heat_capacity_salt
C_p = (specific_heat_capacity_both * (950 + 6)) / 1000 # set heat capacity of water to 4181 j / kg C + salt

dT_dt = round(T_fit.coef[0],4) # set rate of heating to output of polyfit
dT_dt = dT_dt * -1 # turn rate of heating into rate of cooling
Q_est = rho_water * C_p * dT_dt / 1000
print(f'the estimated rate of freezing is {round(Q_est)}')

l_f = 333990 # set specific latent heat of fusion per unit mass to 334,000 j / kg + salt

Mass_ice = Q_est / (l_f)
print(f'the estimated growth of ice in mass per second is {(Mass_ice)}')

rho_ice = 920 # set ice density to 917 kg / m^3 + salt
Volume_ice = Mass_ice/ rho_ice
print(f'the estimated change in volume per second is {(Volume_ice)}')

k_f = 1.96 * 10**9 # set bulk modulus of water to 1.96*10^9 pascals
v_0 = 4/3 * np.pi * 1**3 # set initial sphere volume (as liquid)
pressure_change = Volume_ice * k_f / v_0
print(f'the estimated change in pressure in pascals per second is {(pressure_change)}')
print(f'the estimated change in pressure in millibars per second is {(pressure_change / 100)}')
# Out:
# the estimated rate of freezing is 57
# the estimated growth of ice in mass per second is 0.0001706484242391121
# the estimated change in volume per second is 1.854874176512088e-07
# the estimated change in pressure in pascals per second is 86.79244383758984
# the estimated change in pressure in millibars per second is 0.8679244383758984

# %% [markdown]
# observed strain rate (epsilon dot _observed) = pressure change obs / bulk mod = 10 ^ -7 1 / s  <br>
# epsildon_dot = volume_dot_ice / v_0 = 10 ^ -4 / s

# %% [markdown]
# reproducability! Get 5-10 that have an avg curve that is fairly reproducible.
# pull a sample out halfway to see if ice is growing on the pressure sensor.
# calibration is good. maybe get one more calibration.
# find new pressure sensor
# small bag of anti freeze around pressure sensor in larger bag

# %% [markdown]
# sea freeze is equation of state- can link volume pressure temperature
#
# changing salinity will decrease the latent heat

# %% [markdown]
# use seafreeze: constant volume and freezing rate - determine delta press

# %% [markdown]
# polarized light to look at brine channels (?)
# general idea is that adding salt will make ice structure stronger

# %%
plt.rcParams.update({'font.size': 16})
fig, ax1 = plt.subplots()
ax1.plot((np.array(salt_6_11_28_length) * 30) / 60 / 60, salt_6_11_28[1], 'b', label='Pressure')
ax1.set_xlabel('hours',fontsize=22)
ax1.set_ylabel('millibars', color='b', fontsize = 22)
ax1.tick_params('y', colors='b', labelsize=12)
ax1.set_xticks(np.arange(0, len(length_11_6), step=1))
plt.ylim(0,3500)

ax2 = ax1.twinx()
ax2.plot((np.array(salt_6_11_28_length) * 30) / 60 / 60, salt_6_11_28[3], 'r', label='Temperature', linestyle = '--')
ax2.set_ylabel('°C', color='r', fontsize =22)
ax2.tick_params('y', colors='r', labelsize=12)

ax1.legend(loc='lower left', fontsize=12, bbox_to_anchor=(0, 0.08))
ax2.legend(loc='lower left', fontsize=12)
#plt.suptitle('11/6/23', fontsize = 14)
#plt.title('Salted 6g/l Frozen at -30 °C',fontsize=22)
plt.xlim(2,3.7)
#print('note that this sample was not water or air tight as evidenced by drips through the pressure sensor seal')
#plt.savefig('Pressure Temperature FirstTrial.png', dpi=300, bbox_inches='tight')
#plt.savefig('Pressure_Salt_6g 11-28-23.png', dpi=450, bbox_inches='tight')
plt.axvline(x=2.7, color='k', linestyle='--')
plt.axvline(x=2.85, color='k', linestyle='--')
plt.axvline(x=3.4, color='k', linestyle='--')
plt.show()

# %%
(2.85-2.7)*60
# Out:
# 8.999999999999995

# %%
(3.4 - 2.7) * 60 * 60
# Out:
# 2519.999999999999

# %%
t = salt_6_11_28[3]
plt.plot(q[300:400])
print(q[300] - q[400])
print((q[300] - q[400]) / ((3.4 - 2.7) * 60 * 60))
# Out:
# 22.450719999999997
# 0.008909015873015874

# %%
# calculate change in volume due to thermal contraction
t = salt_6_11_28[3]

Mass_ice = 1000
rho_ice = 0.91
V_0 = Mass_ice/ rho_ice # calculate volume of ice
alpha = 5.1*10**(-5) # coef of linear thermal expansion
beta = 3 * alpha # coef of volumetric thermal expansion ~ 3*alpha
delta_T = t[400] - t[300] # change in temperature during potential thermal contraction
delta_V_contraction = beta * V_0 * delta_T
print(f'{round(delta_V_contraction,2)} L change in volume due to thermal contraction')

# calculate change in pressure due to volume contraction assuming no volume change can occur
K = 8.5 * 10 **(9)# bulk modulus of ice
delta_P_contraction = -K * delta_V_contraction / V_0
print(f'{delta_P_contraction:.2e} Pa change in pressure due to thermal contraction')
# Out:
# -3.77 L change in volume due to thermal contraction
# 2.92e+07 Pa change in pressure due to thermal contraction
