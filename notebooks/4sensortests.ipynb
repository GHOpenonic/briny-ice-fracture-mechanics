# %% [markdown]
# ### This notebook plots test data for 4-sensor ice fracture

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# C:\Users\Openo\anaconda3\lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
# 5-16-24 -5 fresh
delimiters = r'[:,]'
water_data1 = pd.read_csv('4_sensor_data/5-29-24-long-salty/water_data1.csv',sep=delimiters,header=None,engine='python')
length1 = water_data1.index.tolist()

# had error
#water_data2 = pd.read_csv('4_sensor_data/5-29-24-long-salty/water_data2.csv',sep=delimiters,header=None,engine='python')
#length2 = water_data2.index.tolist()

water_data3 = pd.read_csv('4_sensor_data/5-29-24-long-salty/water_data3.csv',sep=delimiters,header=None,engine='python')
length3 = water_data3.index.tolist()

water_data4 = pd.read_csv('4_sensor_data/5-29-24-long-salty/water_data4.csv',sep=delimiters,header=None,engine='python')
length4 = water_data4.index.tolist()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_46548\3348682167.py in <module>
#       1 # 5-16-24 -5 fresh
#       2 delimiters = r'[:,]'
# ----> 3 water_data1 = pd.read_csv('4_sensor_data/5-29-24-long-salty/water_data1.csv',sep=delimiters,header=None,engine='python')
#       4 length1 = water_data1.index.tolist()
#       5
#
# ...

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, sharey=True, figsize=(12, 8))
fig.suptitle('4-1-24 -30', fontsize=24)


# Sensor 1
ax1.plot(water_data1[5]/60/60, water_data1[1], c='b', label='Pressure')
#ax1.set_xlabel('hours', fontsize=22)
ax1.set_ylabel('millibars', color='b', fontsize=22)
ax1.tick_params('y', colors='b', labelsize=12)

#ax1.set_ylim(0, 2000)

ax2_1 = ax1.twinx()
ax2_1.plot(water_data1[5]/60/60, water_data1[3], c='r', label='Temperature', linestyle='--')
ax2_1.set_ylabel('°C', color='r', fontsize=22)
ax2_1.tick_params('y', colors='r', labelsize=12)


ax1.legend(loc='lower left', fontsize=12, bbox_to_anchor=(0, 0.08))
ax2_1.legend(loc='lower left', fontsize=12)

ax1.set_title('Sensor 1: control outside chamber')

# Sensor 2 had error
#ax2.plot(water_data2[5]/60/60, water_data2[1], c='b', label='Pressure')
#ax2.set_xlabel('hours', fontsize=22)


#ax2_2 = ax2.twinx()
#ax2_2.plot(water_data2[5]/60/60, water_data2[3], c='r', label='Temperature', linestyle='--')
#ax2_2.set_ylabel('°C', color='r', fontsize=22)
#ax2_2.tick_params('y', colors='r', labelsize=12)

#ax2.legend(loc='lower left', fontsize=12, bbox_to_anchor=(0, 0.08))
#ax2_2.legend(loc='lower left', fontsize=12)

#ax2.set_title('Sensor 2: control outside chamber')

# Sensor 3
ax3.plot(water_data3[5]/60/60, water_data3[1], c='b', label='Pressure')
ax3.set_xlabel('hours', fontsize=22)
ax3.set_ylabel('millibars', color='b', fontsize=22)
ax3.tick_params('y', colors='b', labelsize=12)

#ax3.set_ylim(0, 3500)
ax3.set_xlim(0,12)

ax3_1 = ax3.twinx()
ax3_1.plot(water_data3[5]/60/60, water_data3[3], c='r', label='Temperature', linestyle='--')
ax3_1.set_ylabel('°C', color='r', fontsize=22)
ax3_1.tick_params('y', colors='r', labelsize=12)

#ax3.legend(loc='lower left', fontsize=12, bbox_to_anchor=(0, 0.08))
#ax3_1.legend(loc='lower left', fontsize=12)


ax3.set_title('Sensor 3: 5 g/l, -5 C. No Fractures Present')

# Sensor 4
ax4.plot(water_data4[5]/60/60, water_data4[1], c='b', label='Pressure')
ax4.set_xlabel('hours', fontsize=22)


ax4_2 = ax4.twinx()
ax4_2.scatter(water_data4[5]/60/60, water_data4[3], c='r', label='Temperature', linestyle='--')
ax4_2.set_ylabel('°C', color='r', fontsize=22)
ax4_2.tick_params('y', colors='r', labelsize=12)

#ax4.legend(loc='lower left', fontsize=12, bbox_to_anchor=(0, 0.08))
#ax4_2.legend(loc='lower left', fontsize=12)

ax4.set_title('Sensor 4: control inside chamber')

plt.tight_layout()
plt.show()

# %%
# 5-16-24 -5 fresh
delimiters = r'[:,]'
water_data1 = pd.read_csv('4_sensor_data/long_run_5_16_24/water_data1.csv',sep=delimiters,header=None,engine='python')
length1 = water_data1.index.tolist()

water_data2 = pd.read_csv('4_sensor_data/long_run_5_16_24/water_data2.csv',sep=delimiters,header=None,engine='python')
length2 = water_data2.index.tolist()

water_data3 = pd.read_csv('4_sensor_data/long_run_5_16_24/water_data3.csv',sep=delimiters,header=None,engine='python')
length3 = water_data3.index.tolist()

water_data4 = pd.read_csv('4_sensor_data/long_run_5_16_24/water_data4.csv',sep=delimiters,header=None,engine='python')
length4 = water_data4.index.tolist()

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, sharey=True, figsize=(12, 8))
fig.suptitle('4-1-24 -30', fontsize=24)


# Sensor 1
ax1.plot(water_data1[5]/60/60, water_data1[1], c='b', label='Pressure')
#ax1.set_xlabel('hours', fontsize=22)
ax1.set_ylabel('millibars', color='b', fontsize=22)
ax1.tick_params('y', colors='b', labelsize=12)

#ax1.set_ylim(0, 2000)

ax2_1 = ax1.twinx()
ax2_1.plot(water_data1[5]/60/60, water_data1[3], c='r', label='Temperature', linestyle='--')
ax2_1.set_ylabel('°C', color='r', fontsize=22)
ax2_1.tick_params('y', colors='r', labelsize=12)


ax1.legend(loc='lower left', fontsize=12, bbox_to_anchor=(0, 0.08))
ax2_1.legend(loc='lower left', fontsize=12)

ax1.set_title('Sensor 1: control outside chamber')

# Sensor 2
ax2.plot(water_data2[5]/60/60, water_data2[1], c='b', label='Pressure')
#ax2.set_xlabel('hours', fontsize=22)


ax2_2 = ax2.twinx()
ax2_2.plot(water_data2[5]/60/60, water_data2[3], c='r', label='Temperature', linestyle='--')
ax2_2.set_ylabel('°C', color='r', fontsize=22)
ax2_2.tick_params('y', colors='r', labelsize=12)

#ax2.legend(loc='lower left', fontsize=12, bbox_to_anchor=(0, 0.08))
#ax2_2.legend(loc='lower left', fontsize=12)

ax2.set_title('Sensor 2: control outside chamber')


# Sensor 3
ax3.plot(water_data3[5]/60/60, water_data3[1], c='b', label='Pressure')
ax3.set_xlabel('hours', fontsize=22)
ax3.set_ylabel('millibars', color='b', fontsize=22)
ax3.tick_params('y', colors='b', labelsize=12)

#ax3.set_ylim(0, 3500)
ax3.set_xlim(0,2)

ax3_1 = ax3.twinx()
ax3_1.plot(water_data3[5]/60/60, water_data3[3], c='r', label='Temperature', linestyle='--')
ax3_1.set_ylabel('°C', color='r', fontsize=22)
ax3_1.tick_params('y', colors='r', labelsize=12)

#ax3.legend(loc='lower left', fontsize=12, bbox_to_anchor=(0, 0.08))
#ax3_1.legend(loc='lower left', fontsize=12)


ax3.set_title('Sensor 3: fresh, -5 C. Fractures Present')

# Sensor 4
ax4.plot(water_data4[5]/60/60, water_data4[1], c='b', label='Pressure')
ax4.set_xlabel('hours', fontsize=22)


ax4_2 = ax4.twinx()
ax4_2.scatter(water_data4[5]/60/60, water_data4[3], c='r', label='Temperature', linestyle='--')
ax4_2.set_ylabel('°C', color='r', fontsize=22)
ax4_2.tick_params('y', colors='r', labelsize=12)

#ax4.legend(loc='lower left', fontsize=12, bbox_to_anchor=(0, 0.08))
#ax4_2.legend(loc='lower left', fontsize=12)

ax4.set_title('Sensor 4: control inside chamber')

plt.tight_layout()
plt.show()

# %%
water_data3[5]/60/60
# Out:
# 0        0.002958
# 1        0.006909
# 2        0.010855
# 3        0.017924
# 4        0.021873
#           ...
# 5646    23.908458
# 5647    23.912761
# 5648    23.917044
# 5649    23.921333
# 5650    23.925619
# Name: 5, Length: 5651, dtype: float64

# %%
print(np.mean(water_data2[1][300:470]))
print(np.mean(water_data3[3][300:470]))
# Out:
# 1013.199688235294
# 0.23584356235294116

# %%
# 4-1-24 -30 1 ppt
delimiters = r'[:,]'
water_data1 = pd.read_csv('4_sensor_data/4-2-24_-30_1ppt/water_data1.csv',sep=delimiters,header=None,engine='python')
length1 = water_data1.index.tolist()

water_data2 = pd.read_csv('4_sensor_data/4-2-24_-30_1ppt/water_data2.csv',sep=delimiters,header=None,engine='python')
length2 = water_data2.index.tolist()

water_data3 = pd.read_csv('4_sensor_data/4-2-24_-30_1ppt/water_data3.csv',sep=delimiters,header=None,engine='python')
length3 = water_data3.index.tolist()

water_data4 = pd.read_csv('4_sensor_data/4-2-24_-30_1ppt/water_data4.csv',sep=delimiters,header=None,engine='python')
length4 = water_data4.index.tolist()

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, sharey=True, figsize=(12, 8))
fig.suptitle('4-1-24 -30', fontsize=24)
#fractures

# Sensor 1
ax1.plot(water_data1[5]/60/60, water_data1[1], c='b', label='Pressure')
#ax1.set_xlabel('hours', fontsize=22)
ax1.set_ylabel('millibars', color='b', fontsize=22)
ax1.tick_params('y', colors='b', labelsize=12)

#ax1.set_ylim(0, 2000)

ax2_1 = ax1.twinx()
ax2_1.plot(water_data1[5]/60/60, water_data1[3], c='r', label='Temperature', linestyle='--')
ax2_1.set_ylabel('°C', color='r', fontsize=22)
ax2_1.tick_params('y', colors='r', labelsize=12)


ax1.legend(loc='lower left', fontsize=12, bbox_to_anchor=(0, 0.08))
ax2_1.legend(loc='lower left', fontsize=12)

ax1.set_title('Sensor 1: control outside chamber')

# Sensor 2
ax2.plot(water_data2[5]/60/60, water_data2[1], c='b', label='Pressure')
#ax2.set_xlabel('hours', fontsize=22)


ax2_2 = ax2.twinx()
ax2_2.plot(water_data2[5]/60/60, water_data2[3], c='r', label='Temperature', linestyle='--')
ax2_2.set_ylabel('°C', color='r', fontsize=22)
ax2_2.tick_params('y', colors='r', labelsize=12)

#ax2.legend(loc='lower left', fontsize=12, bbox_to_anchor=(0, 0.08))
#ax2_2.legend(loc='lower left', fontsize=12)

ax2.set_title('Sensor 2: 1 g/l')

# Sensor 3
ax3.plot(water_data3[5]/60/60, water_data3[1], c='b', label='Pressure')
ax3.set_xlabel('hours', fontsize=22)
ax3.set_ylabel('millibars', color='b', fontsize=22)
ax3.tick_params('y', colors='b', labelsize=12)

#ax3.set_ylim(0, 3500)
ax3.set_xlim(0,4)

ax3_1 = ax3.twinx()
ax3_1.plot(water_data3[5]/60/60, water_data3[3], c='r', label='Temperature', linestyle='--')
ax3_1.set_ylabel('°C', color='r', fontsize=22)
ax3_1.tick_params('y', colors='r', labelsize=12)

#ax3.legend(loc='lower left', fontsize=12, bbox_to_anchor=(0, 0.08))
#ax3_1.legend(loc='lower left', fontsize=12)


ax3.set_title('Sensor 3: 1 g/l')

# Sensor 4
ax4.plot(water_data4[5]/60/60, water_data4[1], c='b', label='Pressure')
ax4.set_xlabel('hours', fontsize=22)


ax4_2 = ax4.twinx()
ax4_2.scatter(water_data4[5]/60/60, water_data4[3], c='r', label='Temperature', linestyle='--')
ax4_2.set_ylabel('°C', color='r', fontsize=22)
ax4_2.tick_params('y', colors='r', labelsize=12)

#ax4.legend(loc='lower left', fontsize=12, bbox_to_anchor=(0, 0.08))
#ax4_2.legend(loc='lower left', fontsize=12)

ax4.set_title('Sensor 4: control inside chamber')

plt.tight_layout()
plt.show()

# %%
print(np.mean(water_data1[1][200:300]))
print(np.mean(water_data3[3][200:300]))
# Out:
# 1015.8832800000001
# -0.206515123

# %% [markdown]
# ### Try letting ice melt and see if the bag is permanently deformed, leave pressure sensor in?
#
# ### Try glassware with lid that locks but can move up and down in cylindrical glass to consistently place pressure sensor

# %%
# Create a 2x2 subplot grid
fig, axs = plt.subplots(2, 2, figsize=(10, 8))

# Plot each subplot
axs[0, 0].plot(water_data3[5]/60/60, water_data3[1])
axs[0, 0].plot(water_data2[5]/60/60, water_data2[1])
axs[0, 0].axvline(x=2.25, c = 'r', linestyle = '--', linewidth = 0.5)
axs[0, 0].axvline(x=2.45, c = 'r', linestyle = '--', linewidth = 0.5)
axs[0, 0].axvline(x=2.75, c = 'r', linestyle = '--', linewidth = 0.5)

axs[0, 1].scatter(water_data3[5]/60/60, water_data3[1], s = 3)
axs[0, 1].scatter(water_data2[5]/60/60, water_data2[1], s = 3)
axs[0, 1].axvline(x=2.25, c = 'r', linestyle = '--', linewidth = 0.5)
axs[0, 1].axvline(x=2.45, c = 'r', linestyle = '--', linewidth = 0.5)
axs[0, 1].axvline(x=2.75, c = 'r', linestyle = '--', linewidth = 0.5)

axs[1, 0].plot(water_data3[5]/60/60, water_data3[1])
axs[1, 0].plot(water_data2[5]/60/60, water_data2[1])
axs[1, 0].set_xlim(2, 3)
axs[1, 0].axvline(x=2.25, c = 'r', linestyle = '--')
axs[1, 0].axvline(x=2.45, c = 'r', linestyle = '--')
axs[1, 0].axvline(x=2.75, c = 'r', linestyle = '--')

axs[1, 1].scatter(water_data3[5]/60/60, water_data3[1], s = 3)
axs[1, 1].scatter(water_data2[5]/60/60, water_data2[1], s = 3)
axs[1, 1].set_xlim(2, 3)
axs[1, 1].axvline(x=2.25, c = 'r', linestyle = '--')
axs[1, 1].axvline(x=2.45, c = 'r', linestyle = '--')
axs[1, 1].axvline(x=2.75, c = 'r', linestyle = '--')

# %%
# 4-1-24 -30 2 sensors in only 1 bag
delimiters = r'[:,]'
water_data1 = pd.read_csv('4_sensor_data/4-1-24_-30_2sensorsin1bag/water_data1.csv',sep=delimiters,header=None,engine='python')
length1 = water_data1.index.tolist()

water_data2 = pd.read_csv('4_sensor_data/4-1-24_-30_2sensorsin1bag/water_data2.csv',sep=delimiters,header=None,engine='python')
length2 = water_data2.index.tolist()

water_data3 = pd.read_csv('4_sensor_data/4-1-24_-30_2sensorsin1bag/water_data3.csv',sep=delimiters,header=None,engine='python')
length3 = water_data3.index.tolist()

water_data4 = pd.read_csv('4_sensor_data/4-1-24_-30_2sensorsin1bag/water_data4.csv',sep=delimiters,header=None,engine='python')
length4 = water_data4.index.tolist()

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, sharey=True, figsize=(12, 8))
fig.suptitle('4-1-24 -30', fontsize=24)


# Sensor 1
ax1.plot(water_data1[5]/60/60, water_data1[1], c='b', label='Pressure')
#ax1.set_xlabel('hours', fontsize=22)
ax1.set_ylabel('millibars', color='b', fontsize=22)
ax1.tick_params('y', colors='b', labelsize=12)

#ax1.set_ylim(0, 2000)

ax2_1 = ax1.twinx()
ax2_1.plot(water_data1[5]/60/60, water_data1[3], c='r', label='Temperature', linestyle='--')
ax2_1.set_ylabel('°C', color='r', fontsize=22)
ax2_1.tick_params('y', colors='r', labelsize=12)


ax1.legend(loc='lower left', fontsize=12, bbox_to_anchor=(0, 0.08))
ax2_1.legend(loc='lower left', fontsize=12)

ax1.set_title('Sensor 1: control outside chamber')

# Sensor 2
ax2.plot(water_data2[5]/60/60, water_data2[1], c='b', label='Pressure')
#ax2.set_xlabel('hours', fontsize=22)


ax2_2 = ax2.twinx()
ax2_2.plot(water_data2[5]/60/60, water_data2[3], c='r', label='Temperature', linestyle='--')
ax2_2.set_ylabel('°C', color='r', fontsize=22)
ax2_2.tick_params('y', colors='r', labelsize=12)

#ax2.legend(loc='lower left', fontsize=12, bbox_to_anchor=(0, 0.08))
#ax2_2.legend(loc='lower left', fontsize=12)

ax2.set_title('Sensor 2: 0 g/l same bag')

# Sensor 3
ax3.plot(water_data3[5]/60/60, water_data3[1], c='b', label='Pressure')
ax3.set_xlabel('hours', fontsize=22)
ax3.set_ylabel('millibars', color='b', fontsize=22)
ax3.tick_params('y', colors='b', labelsize=12)

ax3.set_ylim(0, 3500)
ax3.set_xlim(0,4)

ax3_1 = ax3.twinx()
ax3_1.plot(water_data3[5]/60/60, water_data3[3], c='r', label='Temperature', linestyle='--')
ax3_1.set_ylabel('°C', color='r', fontsize=22)
ax3_1.tick_params('y', colors='r', labelsize=12)

#ax3.legend(loc='lower left', fontsize=12, bbox_to_anchor=(0, 0.08))
#ax3_1.legend(loc='lower left', fontsize=12)

# nof ractures
ax3.set_title('Sensor 3: 0 g/l same bag')

# Sensor 4
ax4.plot(water_data4[5]/60/60, water_data4[1], c='b', label='Pressure')
ax4.set_xlabel('hours', fontsize=22)


ax4_2 = ax4.twinx()
ax4_2.scatter(water_data4[5]/60/60, water_data4[3], c='r', label='Temperature', linestyle='--')
ax4_2.set_ylabel('°C', color='r', fontsize=22)
ax4_2.tick_params('y', colors='r', labelsize=12)

#ax4.legend(loc='lower left', fontsize=12, bbox_to_anchor=(0, 0.08))
#ax4_2.legend(loc='lower left', fontsize=12)

ax4.set_title('Sensor 4: control inside chamber')

plt.tight_layout()
plt.show()

# %%
# Create a 2x2 subplot grid
fig, axs = plt.subplots(2, 2, figsize=(10, 8))

# Plot each subplot
axs[0, 0].plot(water_data3[5]/60/60, water_data3[1])
axs[0, 0].plot(water_data2[5]/60/60, water_data2[1])

axs[0, 1].scatter(water_data3[5]/60/60, water_data3[1], s = 3)
axs[0, 1].scatter(water_data2[5]/60/60, water_data2[1], s = 3)

axs[1, 0].plot(water_data3[5]/60/60, water_data3[1])
axs[1, 0].plot(water_data2[5]/60/60, water_data2[1])
axs[1, 0].set_xlim(1, 1.8)

axs[1, 1].scatter(water_data3[5]/60/60, water_data3[1], s = 3)
axs[1, 1].scatter(water_data2[5]/60/60, water_data2[1], s = 3)
axs[1, 1].set_xlim(1, 1.8)
# Out:
# (1.0, 1.8)

# %%
# 3-28-24 -30
delimiters = r'[:,]'
water_data1 = pd.read_csv('4_sensor_data/3-28-24_-30/water_data1.csv',sep=delimiters,header=None,engine='python')
length1 = water_data1.index.tolist()

water_data2 = pd.read_csv('4_sensor_data/3-28-24_-30/water_data2.csv',sep=delimiters,header=None,engine='python')
length2 = water_data2.index.tolist()

water_data3 = pd.read_csv('4_sensor_data/3-28-24_-30/water_data3.csv',sep=delimiters,header=None,engine='python')
length3 = water_data3.index.tolist()

water_data4 = pd.read_csv('4_sensor_data/3-28-24_-30/water_data4.csv',sep=delimiters,header=None,engine='python')
length4 = water_data4.index.tolist()

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, sharey=True, figsize=(12, 8))
fig.suptitle('3-28-24 -30', fontsize=24)


# Sensor 1
ax1.plot(water_data1[5]/60/60, water_data1[1], c='b', label='Pressure')
#ax1.set_xlabel('hours', fontsize=22)
ax1.set_ylabel('millibars', color='b', fontsize=22)
ax1.tick_params('y', colors='b', labelsize=12)

#ax1.set_ylim(0, 2000)

ax2_1 = ax1.twinx()
ax2_1.plot(water_data1[5]/60/60, water_data1[3], c='r', label='Temperature', linestyle='--')
ax2_1.set_ylabel('°C', color='r', fontsize=22)
ax2_1.tick_params('y', colors='r', labelsize=12)


ax1.legend(loc='lower left', fontsize=12, bbox_to_anchor=(0, 0.08))
ax2_1.legend(loc='lower left', fontsize=12)

ax1.set_title('Sensor 1: control in chamber')

# Sensor 2
ax2.plot(water_data2[5]/60/60, water_data2[1], c='b', label='Pressure')
#ax2.set_xlabel('hours', fontsize=22)


ax2_2 = ax2.twinx()
ax2_2.plot(water_data2[5]/60/60, water_data2[3], c='r', label='Temperature', linestyle='--')
ax2_2.set_ylabel('°C', color='r', fontsize=22)
ax2_2.tick_params('y', colors='r', labelsize=12)

#ax2.legend(loc='lower left', fontsize=12, bbox_to_anchor=(0, 0.08))
#ax2_2.legend(loc='lower left', fontsize=12)

ax2.set_title('Sensor 2: 1 g/l')

# Sensor 3
ax3.plot(water_data3[5]/60/60, water_data3[1], c='b', label='Pressure')
ax3.set_xlabel('hours', fontsize=22)
ax3.set_ylabel('millibars', color='b', fontsize=22)
ax3.tick_params('y', colors='b', labelsize=12)

#ax3.set_ylim(0, 3500)
ax3.set_xlim(0,4)

ax3_1 = ax3.twinx()
ax3_1.plot(water_data3[5]/60/60, water_data3[3], c='r', label='Temperature', linestyle='--')
ax3_1.set_ylabel('°C', color='r', fontsize=22)
ax3_1.tick_params('y', colors='r', labelsize=12)

#ax3.legend(loc='lower left', fontsize=12, bbox_to_anchor=(0, 0.08))
#ax3_1.legend(loc='lower left', fontsize=12)


ax3.set_title('Sensor 3: 0 g/l')

# Sensor 4
ax4.plot(water_data4[5]/60/60, water_data4[1], c='b', label='Pressure')
ax4.set_xlabel('hours', fontsize=22)


ax4_2 = ax4.twinx()
ax4_2.scatter(water_data4[5]/60/60, water_data4[3], c='r', label='Temperature', linestyle='--')
ax4_2.set_ylabel('°C', color='r', fontsize=22)
ax4_2.tick_params('y', colors='r', labelsize=12)

#ax4.legend(loc='lower left', fontsize=12, bbox_to_anchor=(0, 0.08))
#ax4_2.legend(loc='lower left', fontsize=12)

ax4.set_title('Sensor 4: control outside chamber')

plt.tight_layout()
plt.show()

# %%
# 3-27-24 -30
delimiters = r'[:,]'
water_data1 = pd.read_csv('4_sensor_data/3-27-24_-30/water_data1.csv',sep=delimiters,header=None,engine='python')
length1 = water_data1.index.tolist()

water_data2 = pd.read_csv('4_sensor_data/3-27-24_-30/water_data2.csv',sep=delimiters,header=None,engine='python')
length2 = water_data2.index.tolist()

water_data3 = pd.read_csv('4_sensor_data/3-27-24_-30/water_data3.csv',sep=delimiters,header=None,engine='python')
length3 = water_data3.index.tolist()

water_data4 = pd.read_csv('4_sensor_data/3-27-24_-30/water_data4.csv',sep=delimiters,header=None,engine='python')
length4 = water_data4.index.tolist()

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, sharey=True, figsize=(12, 8))
fig.suptitle('3-27-24 -30', fontsize=24)


# Sensor 1
ax1.plot(water_data1[5]/60/60, water_data1[1], c='b', label='Pressure')
#ax1.set_xlabel('hours', fontsize=22)
ax1.set_ylabel('millibars', color='b', fontsize=22)
ax1.tick_params('y', colors='b', labelsize=12)

ax1.set_ylim(0, 2000)

ax2_1 = ax1.twinx()
ax2_1.plot(water_data1[5]/60/60, water_data1[3], c='r', label='Temperature', linestyle='--')
ax2_1.set_ylabel('°C', color='r', fontsize=22)
ax2_1.tick_params('y', colors='r', labelsize=12)


ax1.legend(loc='lower left', fontsize=12, bbox_to_anchor=(0, 0.08))
ax2_1.legend(loc='lower left', fontsize=12)

ax1.set_title('Sensor 1: control in chamber')

# Sensor 2
ax2.plot(water_data2[5]/60/60, water_data2[1], c='b', label='Pressure')
#ax2.set_xlabel('hours', fontsize=22)


ax2_2 = ax2.twinx()
ax2_2.plot(water_data2[5]/60/60, water_data2[3], c='r', label='Temperature', linestyle='--')
ax2_2.set_ylabel('°C', color='r', fontsize=22)
ax2_2.tick_params('y', colors='r', labelsize=12)

#ax2.legend(loc='lower left', fontsize=12, bbox_to_anchor=(0, 0.08))
#ax2_2.legend(loc='lower left', fontsize=12)

ax2.set_title('Sensor 2: control outside chamber')

# Sensor 3
ax3.plot(water_data3[5]/60/60, water_data3[1], c='b', label='Pressure')
ax3.set_xlabel('hours', fontsize=22)
ax3.set_ylabel('millibars', color='b', fontsize=22)
ax3.tick_params('y', colors='b', labelsize=12)

#ax3.set_ylim(0, 3500)
ax3.set_xlim(0,4)

ax3_1 = ax3.twinx()
ax3_1.plot(water_data3[5]/60/60, water_data3[3], c='r', label='Temperature', linestyle='--')
ax3_1.set_ylabel('°C', color='r', fontsize=22)
ax3_1.tick_params('y', colors='r', labelsize=12)
# frac
#ax3.legend(loc='lower left', fontsize=12, bbox_to_anchor=(0, 0.08))
#ax3_1.legend(loc='lower left', fontsize=12)


ax3.set_title('Sensor 3: 0 g/l')

# Sensor 4
ax4.plot(water_data4[5]/60/60, water_data4[1], c='b', label='Pressure')
ax4.set_xlabel('hours', fontsize=22)


ax4_2 = ax4.twinx()
ax4_2.scatter(water_data4[5]/60/60, water_data4[3], c='r', label='Temperature', linestyle='--')
ax4_2.set_ylabel('°C', color='r', fontsize=22)
ax4_2.tick_params('y', colors='r', labelsize=12)

#ax4.legend(loc='lower left', fontsize=12, bbox_to_anchor=(0, 0.08))
#ax4_2.legend(loc='lower left', fontsize=12)

ax4.set_title('Sensor 4: control outside chamber')

plt.tight_layout()
plt.show()

# %%
plt.plot(water_data3[5]/60/60, water_data3[1])
plt.ylim(0,2000)
plt.xlim(0,4)
# Out:
# (0.0, 4.0)

# %%
# 3-26-24 -30
delimiters = r'[:,]'
water_data1 = pd.read_csv('4_sensor_data/3-26-24_-30/water_data1.csv',sep=delimiters,header=None,engine='python')
length1 = water_data1.index.tolist()

water_data2 = pd.read_csv('4_sensor_data/3-26-24_-30/water_data2.csv',sep=delimiters,header=None,engine='python')
length2 = water_data2.index.tolist()

water_data3 = pd.read_csv('4_sensor_data/3-26-24_-30/water_data3.csv',sep=delimiters,header=None,engine='python')
length3 = water_data3.index.tolist()

water_data4 = pd.read_csv('4_sensor_data/3-26-24_-30/water_data4.csv',sep=delimiters,header=None,engine='python')
length4 = water_data4.index.tolist()

# %%
# fix time:
for count, value  in enumerate(water_data1[5]):
    if count > 543:
        (water_data1[5])[count] = value + (water_data1[5])[543]

# fix time:
for count, value  in enumerate(water_data2[5]):
    if count > 526:
        (water_data2[5])[count] = value + (water_data2[5])[526]

# fix time:
for count, value  in enumerate(water_data3[5]):
    if count > 533:
        (water_data3[5])[count] = value + (water_data3[5])[533]

# fix time:
for count, value  in enumerate(water_data4[5]):
    if count > 556:
        (water_data4[5])[count] = value + (water_data4[5])[556]
# Out:
# C:\Users\Openo\AppData\Local\Temp\ipykernel_7020\2025611530.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   (water_data1[5])[count] = value + (water_data1[5])[543]
# C:\Users\Openo\AppData\Local\Temp\ipykernel_7020\2025611530.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   (water_data2[5])[count] = value + (water_data2[5])[526]
# C:\Users\Openo\AppData\Local\Temp\ipykernel_7020\2025611530.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, sharey=True, figsize=(12, 8))
fig.suptitle('3-26-24 -30', fontsize=24)


# Sensor 1
ax1.scatter(water_data1[5]/60/60, water_data1[1], c='b', label='Pressure')
#ax1.set_xlabel('hours', fontsize=22)
ax1.set_ylabel('millibars', color='b', fontsize=22)
ax1.tick_params('y', colors='b', labelsize=12)

ax1.set_ylim(0, 2000)

ax2_1 = ax1.twinx()
ax2_1.scatter(water_data1[5]/60/60, water_data1[3], c='r', label='Temperature', linestyle='--')
#ax2_1.set_ylabel('°C', color='r', fontsize=22)
#ax2_1.tick_params('y', colors='r', labelsize=12)
# no frac
ax2_1.set_yticks([])

ax1.legend(loc='lower left', fontsize=12, bbox_to_anchor=(0, 0.08))
ax2_1.legend(loc='lower left', fontsize=12)

ax1.set_title('Sensor 1: 0.0 g/l')

# Sensor 2
ax2.plot(water_data2[5]/60/60, water_data2[1], c='b', label='Pressure')
#ax2.set_xlabel('hours', fontsize=22)


ax2_2 = ax2.twinx()
ax2_2.plot(water_data2[5]/60/60, water_data2[3], c='r', label='Temperature', linestyle='--')
ax2_2.set_ylabel('°C', color='r', fontsize=22)
ax2_2.tick_params('y', colors='r', labelsize=12)

#ax2.legend(loc='lower left', fontsize=12, bbox_to_anchor=(0, 0.08))
#ax2_2.legend(loc='lower left', fontsize=12)
# n frac
ax2.set_title('Sensor 2: 1.0 g/l')

# Sensor 3
ax3.scatter(water_data3[5]/60/60, water_data3[1], c='b', label='Pressure')
ax3.set_xlabel('hours', fontsize=22)
ax3.set_ylabel('millibars', color='b', fontsize=22)
ax3.tick_params('y', colors='b', labelsize=12)

#ax3.set_ylim(0, 3500)

ax3_1 = ax3.twinx()
ax3_1.plot(water_data3[5]/60/60, water_data3[3], c='r', label='Temperature', linestyle='--')
#ax3_1.set_ylabel('°C', color='r', fontsize=22)
#ax3_1.tick_params('y', colors='r', labelsize=12)

#ax3.legend(loc='lower left', fontsize=12, bbox_to_anchor=(0, 0.08))
#ax3_1.legend(loc='lower left', fontsize=12)

ax3_1.set_yticks([])

ax3.set_title('Sensor 3: control outside chamber')

# Sensor 4
ax4.scatter(water_data4[5]/60/60, water_data4[1], c='b', label='Pressure')
ax4.set_xlabel('hours', fontsize=22)


ax4_2 = ax4.twinx()
ax4_2.scatter(water_data4[5]/60/60, water_data4[3], c='r', label='Temperature', linestyle='--')
ax4_2.set_ylabel('°C', color='r', fontsize=22)
ax4_2.tick_params('y', colors='r', labelsize=12)

#ax4.legend(loc='lower left', fontsize=12, bbox_to_anchor=(0, 0.08))
#ax4_2.legend(loc='lower left', fontsize=12)

ax4.set_title('Sensor 4: control in chamber')

plt.tight_layout()
plt.show()

# %%
# 3-14-24 incomplete
delimiters = r'[:,]'
water_data1 = pd.read_csv('4_sensor_data/3-14-24_-30/water_data1.csv',sep=delimiters,header=None,engine='python')
length1 = water_data1.index.tolist()

water_data2 = pd.read_csv('4_sensor_data/3-14-24_-30/water_data2.csv',sep=delimiters,header=None,engine='python')
length2 = water_data2.index.tolist()

water_data3 = pd.read_csv('4_sensor_data/3-14-24_-30/water_data3.csv',sep=delimiters,header=None,engine='python')
length3 = water_data3.index.tolist()

water_data4 = pd.read_csv('4_sensor_data/3-14-24_-30/water_data4.csv',sep=delimiters,header=None,engine='python')
length4 = water_data4.index.tolist()

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, sharey=True, figsize=(12, 8))
fig.suptitle('3-14-24 -30', fontsize=24)


# Sensor 1
ax1.scatter(water_data1[5]/60/60, water_data1[1], c='b', label='Pressure')
#ax1.set_xlabel('hours', fontsize=22)
ax1.set_ylabel('millibars', color='b', fontsize=22)
ax1.tick_params('y', colors='b', labelsize=12)

#ax1.set_ylim(0, 3500)

ax2_1 = ax1.twinx()
ax2_1.plot(water_data1[5]/60/60, water_data1[3], c='r', label='Temperature', linestyle='--')
#ax2_1.set_ylabel('°C', color='r', fontsize=22)
#ax2_1.tick_params('y', colors='r', labelsize=12)

ax2_1.set_yticks([])

ax1.legend(loc='lower left', fontsize=12, bbox_to_anchor=(0, 0.08))
ax2_1.legend(loc='lower left', fontsize=12)

ax1.set_title('Sensor 1: 0.7 g/l')

# Sensor 2
ax2.scatter(water_data2[5]/60/60, water_data2[1], c='b', label='Pressure')
#ax2.set_xlabel('hours', fontsize=22)


ax2_2 = ax2.twinx()
ax2_2.plot(water_data2[5]/60/60, water_data2[3], c='r', label='Temperature', linestyle='--')
ax2_2.set_ylabel('°C', color='r', fontsize=22)
ax2_2.tick_params('y', colors='r', labelsize=12)

#ax2.legend(loc='lower left', fontsize=12, bbox_to_anchor=(0, 0.08))
#ax2_2.legend(loc='lower left', fontsize=12)

ax2.set_title('Sensor 2: 0 g/l')

# Sensor 3
ax3.scatter(water_data3[5]/60/60, water_data3[1], c='b', label='Pressure')
ax3.set_xlabel('hours', fontsize=22)
ax3.set_ylabel('millibars', color='b', fontsize=22)
ax3.tick_params('y', colors='b', labelsize=12)

#ax3.set_ylim(0, 3500)

ax3_1 = ax3.twinx()
ax3_1.plot(water_data3[5]/60/60, water_data3[3], c='r', label='Temperature', linestyle='--')
#ax3_1.set_ylabel('°C', color='r', fontsize=22)
#ax3_1.tick_params('y', colors='r', labelsize=12)

#ax3.legend(loc='lower left', fontsize=12, bbox_to_anchor=(0, 0.08))
#ax3_1.legend(loc='lower left', fontsize=12)

ax3_1.set_yticks([])

ax3.set_title('Sensor 3: 0.7 g/l')

# Sensor 4
ax4.scatter(water_data4[5]/60/60, water_data4[1], c='b', label='Pressure')
ax4.set_xlabel('hours', fontsize=22)


ax4_2 = ax4.twinx()
ax4_2.plot(water_data4[5]/60/60, water_data4[3], c='r', label='Temperature', linestyle='--')
ax4_2.set_ylabel('°C', color='r', fontsize=22)
ax4_2.tick_params('y', colors='r', labelsize=12)

#ax4.legend(loc='lower left', fontsize=12, bbox_to_anchor=(0, 0.08))
#ax4_2.legend(loc='lower left', fontsize=12)

ax4.set_title('Sensor 4: 0 g/l')

plt.tight_layout()
plt.show()

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, sharey=True, figsize=(12, 8))
fig.suptitle('3-14-24 -30', fontsize=24)


# Sensor 1
ax1.plot(water_data1[5]/60/60, water_data1[1], c='b', label='Pressure')
#ax1.set_xlabel('hours', fontsize=22)
ax1.set_ylabel('millibars', color='b', fontsize=22)
ax1.tick_params('y', colors='b', labelsize=12)

#ax1.set_ylim(0, 3500)

ax2_1 = ax1.twinx()
ax2_1.plot(water_data1[5]/60/60, water_data1[3], c='r', label='Temperature', linestyle='--')
#ax2_1.set_ylabel('°C', color='r', fontsize=22)
#ax2_1.tick_params('y', colors='r', labelsize=12)

ax2_1.set_yticks([])

ax1.legend(loc='lower left', fontsize=12, bbox_to_anchor=(0, 0.08))
ax2_1.legend(loc='lower left', fontsize=12)

ax1.set_title('Sensor 1: 0.7 g/l')

# Sensor 2
ax2.plot(water_data2[5]/60/60, water_data2[1], c='b', label='Pressure')
#ax2.set_xlabel('hours', fontsize=22)


ax2_2 = ax2.twinx()
ax2_2.plot(water_data2[5]/60/60, water_data2[3], c='r', label='Temperature', linestyle='--')
ax2_2.set_ylabel('°C', color='r', fontsize=22)
ax2_2.tick_params('y', colors='r', labelsize=12)

#ax2.legend(loc='lower left', fontsize=12, bbox_to_anchor=(0, 0.08))
#ax2_2.legend(loc='lower left', fontsize=12)

ax2.set_title('Sensor 2: 0 g/l')

# Sensor 3
ax3.plot(water_data3[5]/60/60, water_data3[1], c='b', label='Pressure')
ax3.set_xlabel('hours', fontsize=22)
ax3.set_ylabel('millibars', color='b', fontsize=22)
ax3.tick_params('y', colors='b', labelsize=12)

#ax3.set_ylim(0, 3500)

ax3_1 = ax3.twinx()
ax3_1.plot(water_data3[5]/60/60, water_data3[3], c='r', label='Temperature', linestyle='--')
#ax3_1.set_ylabel('°C', color='r', fontsize=22)
#ax3_1.tick_params('y', colors='r', labelsize=12)

#ax3.legend(loc='lower left', fontsize=12, bbox_to_anchor=(0, 0.08))
#ax3_1.legend(loc='lower left', fontsize=12)

ax3_1.set_yticks([])

ax3.set_title('Sensor 3: 0.7 g/l')

# Sensor 4
ax4.plot(water_data4[5]/60/60, water_data4[1], c='b', label='Pressure')
ax4.set_xlabel('hours', fontsize=22)


ax4_2 = ax4.twinx()
ax4_2.plot(water_data4[5]/60/60, water_data4[3], c='r', label='Temperature', linestyle='--')
ax4_2.set_ylabel('°C', color='r', fontsize=22)
ax4_2.tick_params('y', colors='r', labelsize=12)

#ax4.legend(loc='lower left', fontsize=12, bbox_to_anchor=(0, 0.08))
#ax4_2.legend(loc='lower left', fontsize=12)

ax4.set_title('Sensor 4: 0 g/l')

plt.tight_layout()
plt.show()

# %%
# 3-13-24 incomplete
delimiters = r'[:,]'
water_data1 = pd.read_csv('4_sensor_data/3-13-24 - incomplete/water_data1.csv',sep=delimiters,header=None,engine='python')
length1 = water_data1.index.tolist()

water_data2 = pd.read_csv('4_sensor_data/3-13-24 - incomplete/water_data2.csv',sep=delimiters,header=None,engine='python')
length2 = water_data2.index.tolist()

water_data3 = pd.read_csv('4_sensor_data/3-13-24 - incomplete/water_data3.csv',sep=delimiters,header=None,engine='python')
length3 = water_data3.index.tolist()

water_data4 = pd.read_csv('4_sensor_data/3-13-24 - incomplete/water_data4.csv',sep=delimiters,header=None,engine='python')
length4 = water_data4.index.tolist()

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, sharey=True, figsize=(12, 8))
fig.suptitle('3-13-24 Incomplete Run', fontsize=24)


# Sensor 1
ax1.scatter(water_data1[5]/60/60, water_data1[1], c='b', label='Pressure')
#ax1.set_xlabel('hours', fontsize=22)
ax1.set_ylabel('millibars', color='b', fontsize=22)
ax1.tick_params('y', colors='b', labelsize=12)

#ax1.set_ylim(0, 3500)

ax2_1 = ax1.twinx()
ax2_1.plot(water_data1[5]/60/60, water_data1[3], c='r', label='Temperature', linestyle='--')
#ax2_1.set_ylabel('°C', color='r', fontsize=22)
#ax2_1.tick_params('y', colors='r', labelsize=12)

ax2_1.set_yticks([])

ax1.legend(loc='lower left', fontsize=12, bbox_to_anchor=(0, 0.08))
ax2_1.legend(loc='lower left', fontsize=12)

ax1.set_title('Sensor 1: 0.7 g/l')

# Sensor 2
ax2.scatter(water_data2[5]/60/60, water_data2[1], c='b', label='Pressure')
#ax2.set_xlabel('hours', fontsize=22)


ax2_2 = ax2.twinx()
ax2_2.plot(water_data2[5]/60/60, water_data2[3], c='r', label='Temperature', linestyle='--')
ax2_2.set_ylabel('°C', color='r', fontsize=22)
ax2_2.tick_params('y', colors='r', labelsize=12)

#ax2.legend(loc='lower left', fontsize=12, bbox_to_anchor=(0, 0.08))
#ax2_2.legend(loc='lower left', fontsize=12)

ax2.set_title('Sensor 2: 0 g/l')

# Sensor 3
ax3.scatter(water_data3[5]/60/60, water_data3[1], c='b', label='Pressure')
ax3.set_xlabel('hours', fontsize=22)
ax3.set_ylabel('millibars', color='b', fontsize=22)
ax3.tick_params('y', colors='b', labelsize=12)

#ax3.set_ylim(0, 3500)

ax3_1 = ax3.twinx()
ax3_1.plot(water_data3[5]/60/60, water_data3[3], c='r', label='Temperature', linestyle='--')
#ax3_1.set_ylabel('°C', color='r', fontsize=22)
#ax3_1.tick_params('y', colors='r', labelsize=12)

#ax3.legend(loc='lower left', fontsize=12, bbox_to_anchor=(0, 0.08))
#ax3_1.legend(loc='lower left', fontsize=12)

ax3_1.set_yticks([])

ax3.set_title('Sensor 3: 0.7 g/l')

# Sensor 4
ax4.scatter(water_data4[5]/60/60, water_data4[1], c='b', label='Pressure')
ax4.set_xlabel('hours', fontsize=22)


ax4_2 = ax4.twinx()
ax4_2.plot(water_data4[5]/60/60, water_data4[3], c='r', label='Temperature', linestyle='--')
ax4_2.set_ylabel('°C', color='r', fontsize=22)
ax4_2.tick_params('y', colors='r', labelsize=12)

#ax4.legend(loc='lower left', fontsize=12, bbox_to_anchor=(0, 0.08))
#ax4_2.legend(loc='lower left', fontsize=12)

ax4.set_title('Sensor 4: 0 g/l')

plt.tight_layout()
plt.show()

# %%
# sensors 2 and 3 showed ice growth

# %%
fig, axes = plt.subplots(nrows=4, ncols=2, figsize=(12, 10))

# Plot your data into each subplot
axes[0, 0].scatter(water_data1[5]/60/60, water_data1[1], c='blue')
axes[0, 1].scatter(water_data1[5], water_data1[3], c='red')

axes[1, 0].scatter(water_data2[5], water_data2[1], c='blue')
axes[1, 1].scatter(water_data2[5], water_data2[3], c='red')

axes[2, 0].scatter(water_data3[5], water_data3[1], c='blue') 
axes[2, 1].scatter(water_data3[5], water_data3[3], c='red')

axes[3, 0].scatter(water_data4[5], water_data4[1], c='blue')
axes[3, 1].scatter(water_data4[5], water_data4[3], c='red')

# Set titles and labels
axes[0, 0].set_title('Pressure 1')
axes[0, 1].set_title('Temperature 1')
axes[1, 0].set_title('Pressure 2')
axes[1, 1].set_title('Temperature 2')

axes[2, 0].set_title('Pressure 3')
axes[2, 1].set_title('Temperature 3')
axes[3, 0].set_title('Pressure 4')
axes[3, 1].set_title('Temperature 4')

# Adjust layout and show the plot
plt.tight_layout()
plt.show()

# %%
# environmental chamber calibration
# 3-11-24
delimiters = r'[:,]'
water_data1 = pd.read_csv('new_data/environmental_chamber_calibration/water_data1.csv',sep=delimiters,header=None,engine='python')
length1 = water_data1.index.tolist()

water_data2 = pd.read_csv('new_data/environmental_chamber_calibration/water_data2.csv',sep=delimiters,header=None,engine='python')
length2 = water_data2.index.tolist()

water_data3 = pd.read_csv('new_data/environmental_chamber_calibration/water_data3.csv',sep=delimiters,header=None,engine='python')
length3 = water_data3.index.tolist()

water_data4 = pd.read_csv('new_data/environmental_chamber_calibration/water_data4.csv',sep=delimiters,header=None,engine='python')
length4 = water_data4.index.tolist()

# %%
fig, axes = plt.subplots(nrows=4, ncols=2, figsize=(12, 10))

# Plot your data into each subplot
axes[0, 0].scatter(water_data1[5]/60/60, water_data1[1], c='blue')
axes[0, 1].scatter(water_data1[5], water_data1[3], c='red')

axes[1, 0].scatter(water_data2[5], water_data2[1], c='blue')
axes[1, 1].scatter(water_data2[5], water_data2[3], c='red')

axes[2, 0].scatter(water_data3[5], water_data3[1], c='blue') 
axes[2, 1].scatter(water_data3[5], water_data3[3], c='red')

axes[3, 0].scatter(water_data4[5], water_data4[1], c='blue')
axes[3, 1].scatter(water_data4[5], water_data4[3], c='red')

# Set titles and labels
axes[0, 0].set_title('Pressure 1')
axes[0, 1].set_title('Temperature 1')
axes[1, 0].set_title('Pressure 2')
axes[1, 1].set_title('Temperature 2')

axes[2, 0].set_title('Pressure 3')
axes[2, 1].set_title('Temperature 3')
axes[3, 0].set_title('Pressure 4')
axes[3, 1].set_title('Temperature 4')

# Adjust layout and show the plot
plt.tight_layout()
plt.show()

# %%
# load all data
# 3-6-24
delimiters = r'[:,]'
water_data1 = pd.read_csv('new_data/test3success/water_data1.csv',sep=delimiters,header=None,engine='python')
length1 = water_data1.index.tolist()

water_data2 = pd.read_csv('new_data/test3success/water_data2.csv',sep=delimiters,header=None,engine='python')
length2 = water_data2.index.tolist()

water_data3 = pd.read_csv('new_data/test3success/water_data3.csv',sep=delimiters,header=None,engine='python')
length3 = water_data3.index.tolist()

water_data4 = pd.read_csv('new_data/test3success/water_data4.csv',sep=delimiters,header=None,engine='python')
length4 = water_data4.index.tolist()

# %%
fig, axes = plt.subplots(nrows=4, ncols=2, figsize=(12, 10))

# Plot your data into each subplot
axes[0, 0].scatter(water_data1[5], water_data1[1], c='blue')
axes[0, 1].scatter(water_data1[5], water_data1[3], c='red')

axes[1, 0].scatter(water_data2[5], water_data2[1], c='blue')
axes[1, 1].scatter(water_data2[5], water_data2[3], c='red')

axes[2, 0].scatter(water_data3[5], water_data3[1], c='blue') 
axes[2, 1].scatter(water_data3[5], water_data3[3], c='red')

axes[3, 0].scatter(water_data4[5], water_data4[1], c='blue')
axes[3, 1].scatter(water_data4[5], water_data4[3], c='red')

# Set titles and labels
axes[0, 0].set_title('Pressure 1')
axes[0, 1].set_title('Temperature 1')
axes[1, 0].set_title('Pressure 2')
axes[1, 1].set_title('Temperature 2')

axes[2, 0].set_title('Pressure 3')
axes[2, 1].set_title('Temperature 3')
axes[3, 0].set_title('Pressure 4')
axes[3, 1].set_title('Temperature 4')

# Adjust layout and show the plot
plt.tight_layout()
plt.show()

# %%
# calculate

# %%
fig, axes = plt.subplots(nrows=4, ncols=2, figsize=(12, 10))

# Plot your data into each subplot
axes[0, 0].scatter(water_data1[5], water_data1[1], c='blue')
axes[0, 1].scatter(water_data1[5], water_data1[3], c='red')

axes[1, 0].scatter(water_data2[5], water_data2[1], c='blue')
axes[1, 1].scatter(water_data2[5], water_data2[3], c='red')

axes[2, 0].scatter(water_data3[5], water_data3[1], c='blue') 
axes[2, 1].scatter(water_data3[5], water_data3[3], c='red')

axes[3, 0].scatter(water_data4[5], water_data4[1], c='blue')
axes[3, 1].scatter(water_data4[5], water_data4[3], c='red')

# Set titles and labels
axes[0, 0].set_title('Pressure 1')
axes[0, 1].set_title('Temperature 1')
axes[1, 0].set_title('Pressure 2')
axes[1, 1].set_title('Temperature 2')

axes[2, 0].set_title('Pressure 3')
axes[2, 1].set_title('Temperature 3')
axes[3, 0].set_title('Pressure 4')
axes[3, 1].set_title('Temperature 4')

# Adjust layout and show the plot
plt.tight_layout()
plt.show()

# %%
# load all data
# 3-6-24
delimiters = r'[:,]'
water_data1 = pd.read_csv('new_data/test/water_data1.csv',sep=delimiters,header=None,engine='python')
length1 = water_data1.index.tolist()

water_data2 = pd.read_csv('new_data/test/water_data2.csv',sep=delimiters,header=None,engine='python')
length2 = water_data2.index.tolist()

water_data3 = pd.read_csv('new_data/test/water_data3.csv',sep=delimiters,header=None,engine='python')
length3 = water_data3.index.tolist()

water_data4 = pd.read_csv('new_data/test/water_data4.csv',sep=delimiters,header=None,engine='python')
length4 = water_data4.index.tolist()

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(8, 6))

# Plot your data into each subplot
axes[0, 0].scatter(water_data1[5], water_data1[1], c='blue', label='Data 1')
axes[0, 1].scatter(water_data2[5], water_data2[1], c='green', label='Data 2')
axes[1, 0].scatter(water_data3[5], water_data3[1], c='red', label='Data 3')
axes[1, 1].scatter(water_data4[5], water_data4[1], c='purple', label='Data 4')

# Set titles and labels
axes[0, 0].set_title('Data 1')
axes[0, 1].set_title('Data 2')
axes[1, 0].set_title('Data 3')
axes[1, 1].set_title('Data 4')

# Adjust layout and show the plot
plt.tight_layout()
plt.show()

# %%
delimiters = r'[:,]'
water_data1 = pd.read_csv('new_data/test2/water_data1.csv',sep=delimiters,header=None,engine='python')
length1 = water_data1.index.tolist()

water_data2 = pd.read_csv('new_data/test2/water_data2.csv',sep=delimiters,header=None,engine='python')
length2 = water_data2.index.tolist()

water_data3 = pd.read_csv('new_data/test2/water_data3.csv',sep=delimiters,header=None,engine='python')
length3 = water_data3.index.tolist()

water_data4 = pd.read_csv('new_data/test2/water_data4.csv',sep=delimiters,header=None,engine='python')
length4 = water_data4.index.tolist()

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(8, 6))

# Plot your data into each subplot
axes[0, 0].scatter(water_data1[5], water_data1[1], c='blue', label='Data 1')
axes[0, 1].scatter(water_data2[5], water_data2[1], c='green', label='Data 2')
axes[1, 0].scatter(water_data3[5], water_data3[1], c='red', label='Data 3')
axes[1, 1].scatter(water_data4[5], water_data4[1], c='purple', label='Data 4')

# Set titles and labels
axes[0, 0].set_title('Data 1')
axes[0, 1].set_title('Data 2')
axes[1, 0].set_title('Data 3')
axes[1, 1].set_title('Data 4')

# Adjust layout and show the plot
plt.tight_layout()
plt.show()
